# %%
#Importing Libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('images.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
#Creating Gray Image
grayimage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(grayimage)

# %%
#Creating HSV Image
hsvimage = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(hsvimage)

# %%
#Resizing Images
width = 100
height = 100
smaller_image = cv2.resize(image,(int(width),int(height))) 
plt.imshow(smaller_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-19fa70c994d1> in <module>
#       2 width = 100
#       3 height = 100
# ----> 4 smaller_image = cv2.resize(image,(int(width),int(height)))
#       5 plt.imshow(smaller_image)
#
# NameError: name 'cv2' is not defined
